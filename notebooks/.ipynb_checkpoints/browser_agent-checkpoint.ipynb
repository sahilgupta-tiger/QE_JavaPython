# %%
url = "https://app.powerbi.com/groups/me/apps/3a2f7eaa-1348-456e-80eb-d220d8084583/reports/9a56d70a-3835-4af6-9612-9df3ab8cfa69/222889912d557cc86444?experience=power-bi&bookmarkGuid=9b97320836700128e0e9"

# %%
from browser_use import Agent, Browser, ChatBrowserUse
# from browser_use import ChatGoogle  # ChatGoogle(model='gemini-3-flash-preview')
# from browser_use import ChatAnthropic  # ChatAnthropic(model='claude-sonnet-4-6')
import asyncio

# %%
from browser_use import ChatAzureOpenAI

# %%
# ITC_AZURE_OPENAI_ENDPOINT=https://tigeropenaiservice.openai.azure.com/
# ITC_AZURE_OPENAI_KEY=4feeebf652bd46168c6a863b99314fc9
# ITC_AZURE_OPENAI_MODEL=gpt-4o
# ITC_AZURE_OPENAI_API_VERSION=2024-10-21

llm_model = ChatAzureOpenAI(api_version="2024-10-21",
                azure_endpoint="https://tigeropenaiservice.openai.azure.com/",
                model="gpt-4o",
                api_key="4feeebf652bd46168c6a863b99314fc9")

# %%
browser = Browser(
    # cdp_url=""
    # use_cloud=True,  # Use a stealth browser on Browser Use Cloud
)

task = """Login and then extract the data from all the charts in structured format.

1. Enter this username: your_email_here.
2. Click on Select and wait for user to complete okta.
3. Continue then and wait for the page to load.
4. Extract the data from the top 2 charts.

Return JSON with this structure:
[{"chart_heading": "value", "data": {"kpi_name": "kpi_value"}}]"""

agent = Agent(
    task=task,
    llm=llm_model,
    # llm=ChatGoogle(model='gemini-3-flash-preview'),
    # llm=ChatAnthropic(model='claude-sonnet-4-6'),
    initial_actions=[{"navigate": {"url": url, "new_tab": True}}],
    browser=browser,
)
history = await agent.run()
# Out:
# INFO     [Agent] 🎯 Task: Login and then extract the data from all the charts in structured format.
#
# 1. Enter this username: Seemant.Singh.Contractor@pepsico.com
# 2. Click on Select and wait for user to complete okta.
# 3. Continue then and wait for the page to load.
# 4. Extract the data from the top 2 charts.
#
# Return JSON with this structure:
# [{"chart_heading": "value", "data": {"kpi_name": "kpi_value"}}]
# INFO     [Agent] Starting a browser-use agent with version 0.12.1, with provider=azure and model=gpt-4o
# INFO     [Agent]   ▶️   navigate: url: https://app.powerbi.com/groups/me/apps/3a2f7eaa-1348-456e-80eb-d220d8084583/reports/9a56d70a-3835-4af6-9612-9df3ab8cfa69/222889912d557cc86444?experien..., new_tab: True
# WARNING  [BrowserSession] ⚠️ Page readiness timeout (8.0s, 8361ms) for https://app.powerbi.com/groups/me/apps/3a2f7eaa-1348-456e-80eb-d220d8084583/reports/9a56d70a-3835-4af6-9612-9df3ab8cfa69/222889912d557cc86444?experience=power-bi&bookmarkGuid=9b97320836700128e0e9
# INFO     [tools] 🔗  Opened new tab with url https://app.powerbi.com/groups/me/apps/3a2f7eaa-1348-456e-80eb-d220d8084583/reports/9a56d70a-3835-4af6-9612-9df3ab8cfa69/222889912d557cc86444?experience=power-bi&bookmarkGuid=9b97320836700128e0e9
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 1:
# INFO     [Agent]   👍 Eval: Successfully navigated to the login page. The email input field and submit button are visible.
# INFO     [Agent]   🧠 Memory: The login page is ready for interaction, and I need to input the user's email address and proceed.
# INFO     [Agent]   🎯 Next goal: Input the provided email address into the text field and click Submit.
# INFO     [Agent]   ▶️  [1/2] input: index: 7, text: Seemant.Singh.Contractor@pepsico.com, clear: True
# INFO     [BrowserSession] ⌨️ Typed "Seemant.Singh.Contractor@pepsico.com" into element with index 7
# INFO     [Agent]   ▶️  [2/2] click: index: 41
# INFO     [tools] 🖱️ Clicked button "Submit" id=submitBtn
# WARNING  [cdp_use.client] Received duplicate response for request 202 - ignoring
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 2:
# INFO     [Agent]   👍 Eval: Successfully submitted the email address and initiated the login process.
# INFO     [Agent]   🧠 Memory: The login process has been initiated, and the application is currently loading. Awaiting further interaction or page load completion.
# INFO     [Agent]   🎯 Next goal: Wait for the page to load completely to proceed with extracting data from charts.
# INFO     [Agent]   ▶️   wait: seconds: 10
# INFO     [tools] 🕒 waited for 10 seconds
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 3:
# INFO     [Agent]   👍 Eval: Successfully waited for the page to load, and the Okta verification options are visible.
# INFO     [Agent]   🧠 Memory: The login process is at the Okta verification stage. The user needs to complete this step before proceeding.
# INFO     [Agent]   🎯 Next goal: Click on the 'Select' button to initiate the Okta verification process.
# INFO     [Agent]   ▶️   click: index: 358
# INFO     [tools] 🖱️ Clicked a "Select" aria-label=Select to get a push
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 4:
# INFO     [Agent]   👍 Eval: Successfully clicked the 'Select' button to initiate Okta verification.
# INFO     [Agent]   🧠 Memory: Okta verification has been initiated. Awaiting user completion before proceeding.
# INFO     [Agent]   🎯 Next goal: Wait for the user to complete Okta verification and for the page to load completely.
# INFO     [Agent]   ▶️   wait: seconds: 30
# INFO     [tools] 🕒 waited for 30 seconds
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 5:
# INFO     [Agent] 📋 Exploration nudge injected after 5 steps without a plan
# INFO     [Agent]   👍 Eval: Successfully reached the confirmation page for the user's trust in the domain.
# INFO     [Agent]   🧠 Memory: The login process has progressed to the confirmation page, requiring user interaction to proceed.
# INFO     [Agent]   🎯 Next goal: Click on 'Continue' to proceed with the login process.
# INFO     [Agent]   ▶️   click: index: 12
# INFO     [tools] 🖱️ Clicked input type=submit id=idSIButton9
# INFO     [Agent] 📋 Plan updated with 3 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 6:
# INFO     [Agent]   👍 Eval: The 'Continue' button was clicked successfully, but the page has not yet loaded completely.
# INFO     [Agent]   🧠 Memory: The login process has been completed, and the application is currently loading. Awaiting access to charts for data extraction.
# INFO     [Agent]   🎯 Next goal: Wait for the page to load completely and verify if charts are accessible.
# INFO     [Agent]   ▶️   wait: seconds: 15
# INFO     [tools] 🕒 waited for 15 seconds
# WARNING  [cdp_use.client] Received duplicate response for request 362 - ignoring
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 7:
# INFO     [Agent]   👍 Eval: Successfully waited for the page to load completely, and charts are now accessible.
# INFO     [Agent]   🧠 Memory: Charts are visible on the Executive Summary page. The task is to extract data from the top two charts.
# INFO     [Agent]   🎯 Next goal: Extract data from the top two charts in structured format.
# INFO     [Agent]   ▶️   extract: query: Extract data from the top two charts including headings and KPIs., extract_links: False, start_from_char: 0
# INFO     [tools] 📄 <url>
# https://app.powerbi.com/groups/me/apps/3a2f7eaa-1348-456e-80eb-d220d8084583/reports/9a56d70a-3835-4af6-9612-9df3ab8cfa69/222889912d557cc86444?experience=power-bi&bookmarkGuid=9b97320836700128e0e9
# </url>
# <query>
# Extract data from the top two charts including headings and KPIs.
# </query>
# <result>
# ### Top Two Charts Headings and KPIs:
#
# #### Chart 1: FL Salty Periodic Trend
# - **Heading:** FL Salty Periodic Trend
# - **KPIs:**
#   - P2'25: -3.1%
#   - P3'25: -2.3%
#   - P4'25: -1.9%
#   - P5'25: -4.0%
#   - P6'25: -3.5%
#   - P7'25: -3.3%
#   - P8'25: -2.3%
#
# #### Chart 2: $ Sales % Chg by Product Group
# - **Heading:** $ Sales % Chg by Product Group
# - **KPIs (Q1-Q4 2025):**
#   - FL Macrosnacks:
#     - Q1: -1.1%
#     - Q2: -2.6%
#     - Q3: -3.4%
#     - Q4: -2.5%
#   - FL Savory:
#     - Q1: -1.1%
#     - Q2: -2.6%
#     - Q3: -3.4%
#     - Q4: -2.6%
#   - FL Salty:
#     - Q1: -0.7%
#     - Q2: -2.4%
#     - Q3: -3.1%
#     - Q4: -2.3%
#   - FL Dips:
#     - Q1: -5.3%
#     - Q2: -5.4%
#     - Q3: -5.0%
#     - Q4: -2.7%
# </result>
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 8:
# INFO     [Agent]   👍 Eval: Successfully extracted data from the top two charts in structured format.
# INFO     [Agent]   🧠 Memory: Extracted data from the top two charts on the Executive Summary page. Charts include 'FL Salty Periodic Trend' and '$ Sales % Chg by Product Group'.
# INFO     [Agent]   🎯 Next goal: Prepare and return the extracted data in the requested JSON format.
# INFO     [Agent]   ▶️   done: text: [{"chart_heading": "FL Salty Periodic Trend", "data": {"P2'25": "-3.1%", "P3'25": "-2.3%", "P4'25": "-1.9%", "P5'25": "-4.0%", "P6'25": "-3.5%", "P7'2..., success: True, files_to_display: None
# INFO     [Agent]
# 📄  Final Result:
# [{"chart_heading": "FL Salty Periodic Trend", "data": {"P2'25": "-3.1%", "P3'25": "-2.3%", "P4'25": "-1.9%", "P5'25": "-4.0%", "P6'25": "-3.5%", "P7'25": "-3.3%", "P8'25": "-2.3%"}}, {"chart_heading": "$ Sales % Chg by Product Group", "data": {"FL Macrosnacks Q1 2025": "-1.1%", "FL Macrosnacks Q2 2025": "-2.6%", "FL Macrosnacks Q3 2025": "-3.4%", "FL Macrosnacks Q4 2025": "-2.5%", "FL Savory Q1 2025": "-1.1%", "FL Savory Q2 2025": "-2.6%", "FL Savory Q3 2025": "-3.4%", "FL Savory Q4 2025": "-2.6%", "FL Salty Q1 2025": "-0.7%", "FL Salty Q2 2025": "-2.4%", "FL Salty Q3 2025": "-3.1%", "FL Salty Q4 2025": "-2.3%", "FL Dips Q1 2025": "-5.3%", "FL Dips Q2 2025": "-5.4%", "FL Dips Q3 2025": "-5.0%", "FL Dips Q4 2025": "-2.7%"}}]
#
#
# INFO     [Agent] ✅ Task completed successfully
# INFO     [BrowserSession] 📢 on_BrowserStopEvent - Calling reset() (force=True, keep_alive=None)
# INFO     [BrowserSession] [SessionManager] Cleared all owned data (targets, sessions, mappings)
# INFO     [BrowserSession] ✅ Browser session reset complete
# INFO     [BrowserSession] ✅ Browser session reset complete

# %%
history
# Out:
# AgentHistoryList(all_results=[ActionResult(is_done=False, success=None, judgement=None, error=None, attachments=None, images=None, long_term_memory='Opened new tab with URL https://app.powerbi.com/groups/me/apps/3a2f7eaa-1348-456e-80eb-d220d8084583/reports/9a56d70a-3835-4af6-9612-9df3ab8cfa69/222889912d557cc86444?experience=power-bi&bookmarkGuid=9b97320836700128e0e9', extracted_content='🔗  Opened new tab with url https://app.powerbi.com/groups/me/apps/3a2f7eaa-1348-456e-80eb-d220d8084583/reports/9a56d70a-3835-4af6-9612-9df3ab8cfa69/222889912d557cc86444?experience=power-bi&bookmarkGuid=9b97320836700128e0e9', include_extracted_content_only_once=False, metadata=None, include_in_memory=False), ActionResult(is_done=False, success=None, judgement=None, error=None, attachments=None, images=None, long_term_memory="Typed 'Seemant.Singh.Contractor@pepsico.com'", extracted_content="Typed 'Seemant.Singh.Contractor@pepsico.com'", include_extracted_content_only_once=False, metadata={'input_x': 407.5, 'input_y': 304.0}, include_in_memory=False), ActionResult(is_done=False, success=None, judgement=None, error=None, attachments=None, images=None, long_term_memory=None, extracted_content='Clicked button "Submit" id=submitBtn', include_extracted_content_only_once=False, metadata={'click_x': 262.171875, 'click_y': 478.0}, include_in_memory=False), ActionResult(is_done=False, success=None, judgement=None, error=None, attachments=None, images=None, long_term_memory='Waited for 30 seconds', extracted_content='Waited for 30 seconds', include_extracted_content_only_once=False, metadata=None, include_in_memory=False), ActionResult(is_done=False, success=None, judgement=None, error=None, attachments=None, images=None, long_term_memory=None, extracted_content='Clicked a "Select" aria-label=Select to get a push', include_extracted_content_only_once=False, metadata={'click_x': 793.234375, 'click_y': 261.09375}, include_in_memory=False), ActionResult(is_done=False, success=None, judgement=None, error=None, attachments=None, images=None, long_term_memory='Waited for 30 seconds', extracted_content='Waited for 30 seconds', include_extracted_content_only_once=False, metadata=None, include_in_memory=False), ActionResult(is_done=False, success=None, judgement=None, error=None, attachments=None, images=None, long_term_memory=None, extracted_content='Clicked input type=submit id=idSIButton9', include_extracted_content_only_once=False, metadata={'click_x': 804.5, 'click_y': 440.71875}, include_in_memory=False), ActionResult(is_done=False, success=None, judgement=None, error=None, attachments=None, images=None, long_term_memory='Waited for 30 seconds', extracted_content='Waited for 30 seconds', include_extracted_content_only_once=False, metadata=None, include_in_memory=False), ActionResult(is_done=False, success=None, judgement=None, error=None, attachments=None, images=None, long_term_memory="<url>\nhttps://app.powerbi.com/groups/me/apps/3a2f7eaa-1348-456e-80eb-d220d8084583/reports/9a56d70a-3835-4af6-9612-9df3ab8cfa69/222889912d557cc86444?experience=power-bi&bookmarkGuid=9b97320836700128e0e9\n</url>\n<query>\nExtract all chart data displayed on the page in a structured format.\n</query>\n<result>\nThe webpage contains various chart data related to performance metrics, sales changes, and trends. Below is the structured extraction of the chart data:\n\n### Chart Data Extracted:\n1. **Category % Change (Cat % Chg):**\n   - 0.0% ▼\n   - -3.8% ▼\n   - -3.2% ▼\n   - -2.2% ▼\n\n2. **Points Change:**\n   - 17.7 pts\n   - 15.3 pts\n   - -0.6 pts ▼\n   - 0.3 pts ▲\n\n3. **Category % Change (Cat % Chg):**\n   - -0.8% ▼\n   - -3.7% ▼\n   - -3.1% ▼\n   - -1.5% ▼\n\n4. **Points Change:**\n   - 31.6 pts\n   - 35.2 pts\n   - -0.8 pts ▼\n   - 0.7 pts ▲\n\n5. **Category % Change (Cat % Chg):**\n   - -0.8% ▼\n   - -1.5% ▼\n   - -2.8% ▼\n   - -1.3% ▼\n\n6. **Points Change:**\n   - 57.5 pts\n   - 53.1 pts\n   - -1.2 pts ▼\n   - 0.1 pts ▲\n\n7. **Category % Change (Cat % Chg):**\n   - FL ...

# %%
eval(history.final_result())
# Out:
# [{'chart_heading': 'FL Salty Periodic Trend',
#   'data': {"P2'25": '-3.1%',
#    "P3'25": '-2.3%',
#    "P4'25": '-1.9%',
#    "P5'25": '-4.0%',
#    "P6'25": '-3.5%',
#    "P7'25": '-3.3%',
#    "P8'25": '-2.3%'}},
#  {'chart_heading': '$ Sales % Chg by Product Group',
#   'data': {'FL Macrosnacks Q1 2025': '-1.1%',
#    'FL Macrosnacks Q2 2025': '-2.6%',
#    'FL Macrosnacks Q3 2025': '-3.4%',
#    'FL Macrosnacks Q4 2025': '-2.5%',
#    'FL Savory Q1 2025': '-1.1%',
#    'FL Savory Q2 2025': '-2.6%',
#    'FL Savory Q3 2025': '-3.4%',
#    'FL Savory Q4 2025': '-2.6%',
#    'FL Salty Q1 2025': '-0.7%',
#    'FL Salty Q2 2025': '-2.4%',
#    'FL Salty Q3 2025': '-3.1%',
#    'FL Salty Q4 2025': '-2.3%',
#    'FL Dips Q1 2025': '-5.3%',
#    'FL Dips Q2 2025': '-5.4%',
#    'FL Dips Q3 2025': '-5.0%',
#    'FL Dips Q4 2025': '-2.7%'}}]
